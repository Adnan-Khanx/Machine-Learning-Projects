# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('D:\pycharm\Datasets\churn_data.csv')
df.head(20)
# Out:
#      user  churn   age housing  credit_score  deposits  withdrawal  \
# 0   55409      0  37.0      na           NaN         0           0
# 1   23547      0  28.0       R         486.0         0           0
# 2   58313      0  35.0       R         561.0        47           2
# 3    8095      0  26.0       R         567.0        26           3
# 4   61353      1  27.0      na           NaN         0           0
# 5    3120      1  32.0       R         567.0         5           3
# 6   41406      0  21.0      na         475.0         0           0
# 7   67679      0  24.0      na           NaN         0           0
# 8   21269      0  28.0       R         548.0         0           0
# 9   25788      0  23.0      na         658.0         1           0
# 10  13840      0  32.0       R           NaN         0           0
# 11  25899      0  41.0       O         625.0        14           0
# 12  20839      0  20.0      na         550.0         0           0
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ## EDA and Data Cleansing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27000 entries, 0 to 26999
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user                     27000 non-null  int64
#  1   churn                    27000 non-null  int64
#  2   age                      26996 non-null  float64
#  3   housing                  27000 non-null  object
#  4   credit_score             18969 non-null  float64
#  5   deposits                 27000 non-null  int64
#  6   withdrawal               27000 non-null  int64
#  7   purchases_partners       27000 non-null  int64
#  8   purchases                27000 non-null  int64
#  9   cc_taken                 27000 non-null  int64
#  10  cc_recommended           27000 non-null  int64
#  11  cc_disliked              27000 non-null  int64
#  12  cc_liked                 27000 non-null  int64
#  13  cc_application_begin     27000 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                            count          mean           std   min      25%  \
# user                     27000.0  35422.702519  20321.006678   1.0  17810.5
# churn                    27000.0      0.413852      0.492532   0.0      0.0
# age                      26996.0     32.219921      9.964838  17.0     25.0
# credit_score             18969.0    542.944225     61.059315   2.0    507.0
# deposits                 27000.0      3.341556      9.131406   0.0      0.0
# withdrawal               27000.0      0.307000      1.055416   0.0      0.0
# purchases_partners       27000.0     28.062519     42.219686   0.0      0.0
# purchases                27000.0      3.273481      8.953077   0.0      0.0
# cc_taken                 27000.0      0.073778      0.437299   0.0      0.0
# cc_recommended           27000.0     92.625778     88.869343   0.0     10.0
# cc_disliked              27000.0      0.050630      0.871366   0.0      0.0
# ...

# %%
df[['purchases_partners']].boxplot()

# %%
df.isna().sum()
# Out:
# user                          0
# churn                         0
# age                           4
# housing                       0
# credit_score               8031
# deposits                      0
# withdrawal                    0
# purchases_partners            0
# purchases                     0
# cc_taken                      0
# cc_recommended                0
# cc_disliked                   0
# cc_liked                      0
# cc_application_begin          0
# app_downloaded                0
# web_user                      0
# app_web_user                  0
# ios_user                      0
# android_user                  0
# registered_phones             0
# payment_type                  0
# waiting_4_loan                0
# cancelled_loan                0
# received_loan                 0
# rejected_loan                 0
# zodiac_sign                   0
# left_for_two_month_plus       0
# left_for_one_month            0
# rewards_earned             3227
# ...

# %%
df['rewards_earned'].value_counts()
# Out:
# 2.0      1277
# 1.0      1241
# 4.0       709
# 3.0       657
# 6.0       537
#          ...
# 86.0        2
# 88.0        1
# 114.0       1
# 99.0        1
# 90.0        1
# Name: rewards_earned, Length: 91, dtype: int64

# %%
df['rewards_earned']=df['rewards_earned'].replace(to_replace=np.nan,value=0)

# %%
df['rewards_earned'].isna().sum()
# Out:
# 0

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# user                       0
# churn                      0
# age                        0
# housing                    0
# credit_score               0
# deposits                   0
# withdrawal                 0
# purchases_partners         0
# purchases                  0
# cc_taken                   0
# cc_recommended             0
# cc_disliked                0
# cc_liked                   0
# cc_application_begin       0
# app_downloaded             0
# web_user                   0
# app_web_user               0
# ios_user                   0
# android_user               0
# registered_phones          0
# payment_type               0
# waiting_4_loan             0
# cancelled_loan             0
# received_loan              0
# rejected_loan              0
# zodiac_sign                0
# left_for_two_month_plus    0
# left_for_one_month         0
# rewards_earned             0
# reward_rate                0
# is_referred                0
# dtype: int64

# %%
df.shape
# Out:
# (18969, 31)

# %%
df.head(10)
# Out:
#      user  churn   age housing  credit_score  deposits  withdrawal  \
# 1   23547      0  28.0       R         486.0         0           0
# 2   58313      0  35.0       R         561.0        47           2
# 3    8095      0  26.0       R         567.0        26           3
# 5    3120      1  32.0       R         567.0         5           3
# 6   41406      0  21.0      na         475.0         0           0
# 8   21269      0  28.0       R         548.0         0           0
# 9   25788      0  23.0      na         658.0         1           0
# 11  25899      0  41.0       O         625.0        14           0
# 12  20839      0  20.0      na         550.0         0           0
# 13  13019      0  27.0       O         567.0         2           1
#
#     purchases_partners  purchases  cc_taken  ...  waiting_4_loan  \
# 1                    1          0         0  ...               0
# 2                   86         47         0  ...               0
# ...

# %%
numerical_columns=df.select_dtypes(include=np.number)

# %%
numerical_columns.shape
# Out:
# (18969, 28)

# %%
plt.figure(figsize=(13,14))
plt.suptitle('histogram of numerical columns',fontsize=20)

for i in range(1,numerical_columns.shape[1]+1):
    plt.subplot(6,5,i)
    plt.subplots_adjust()
    f=plt.gca()
    
    f.axes.get_yaxis().set_visible(False)
    f.set_title(numerical_columns.columns.values[i-1])
    vals=np.size(numerical_columns.iloc[:,i-1].unique())
    values=[numerical_columns.iloc[:,i-1]]
    plt.hist(values, bins = vals, color = "#F7411A")
    plt.subplots_adjust(hspace=0.9, top = 0.9)
plt.tight_layout(rect=[0,0.03,1,0.95])

# %%
df.columns
# Out:
# Index(['user', 'churn', 'age', 'housing', 'credit_score', 'deposits',
#        'withdrawal', 'purchases_partners', 'purchases', 'cc_taken',
#        'cc_recommended', 'cc_disliked', 'cc_liked', 'cc_application_begin',
#        'app_downloaded', 'web_user', 'app_web_user', 'ios_user',
#        'android_user', 'registered_phones', 'payment_type', 'waiting_4_loan',
#        'cancelled_loan', 'received_loan', 'rejected_loan', 'zodiac_sign',
#        'left_for_two_month_plus', 'left_for_one_month', 'rewards_earned',
#        'reward_rate', 'is_referred'],
#       dtype='object')

# %%
# Pie plots visualization   
dataset2 = df[['housing','is_referred','app_downloaded','web_user',
                    'ios_user','app_web_user','waiting_4_loan', 'cancelled_loan',
                    'received_loan','rejected_loan','zodiac_sign',
                    'left_for_two_month_plus','left_for_one_month']]
plt.figure(figsize=(15,15))
plt.suptitle('pi chart', fontsize=20)
for i in range(1,dataset2.shape[1]+1):
    plt.subplot(6,5,i)
    plt.subplots_adjust()
    f=plt.gca()
    
    f.axes.get_yaxis().set_visible(False)
    f.set_title(dataset2.columns.values[i-1])
    values = dataset2.iloc[:, i - 1].value_counts(normalize= True).values
    labels = dataset2.iloc[:, i - 1].value_counts(normalize= True).index
    colors=['#E9D509','#99EC0F','#808B96','#EC7C61','#581845','y','m']
    plt.pie(values, labels = labels,colors=colors,autopct='%1.1f%%')
    plt.axis('equal')
plt.tight_layout(rect=[0,0.03,1,0.95])

# %%
df[dataset2.waiting_4_loan == 1].churn.value_counts()
# Out:
# 0    15
# 1     3
# Name: churn, dtype: int64

# %%
dataset3 = df.drop(columns = ['churn','user','housing','payment_type','zodiac_sign'])

# %%
dataset3.corrwith(df.churn).plot.bar(figsize=(20,10),title='correlation with churn response',fontsize=15,rot=45,grid=True,color=colors)

# %%
df.columns
# Out:
# Index(['user', 'churn', 'age', 'housing', 'credit_score', 'deposits',
#        'withdrawal', 'purchases_partners', 'purchases', 'cc_taken',
#        'cc_recommended', 'cc_disliked', 'cc_liked', 'cc_application_begin',
#        'app_downloaded', 'web_user', 'app_web_user', 'ios_user',
#        'android_user', 'registered_phones', 'payment_type', 'waiting_4_loan',
#        'cancelled_loan', 'received_loan', 'rejected_loan', 'zodiac_sign',
#        'left_for_two_month_plus', 'left_for_one_month', 'rewards_earned',
#        'reward_rate', 'is_referred'],
#       dtype='object')

# %%
import seaborn as sns
sns.set(style="white")
plt.figure(figsize=(20,10))
sns.heatmap(df.drop(columns=['user','churn']).corr(),annot=True)

# %% [markdown]
# ## Let's Remove the upper training using masking

# %%
corr = df.drop(columns = ['user','churn']).corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f,ax=plt.subplots(figsize=(18,25))

cmap=sns.diverging_palette(250,10,as_cmap=True)
sns.heatmap(corr,mask=mask,annot=True,cmap=cmap,robust=True,center=0,square=True, linewidths=.5,cbar_kws={"shrink":.5})

# %%
mask.shape
# Out:
# (26, 26)

# %%
df.shape
# Out:
# (18969, 31)

# %%
df=pd.get_dummies(df)

# %%
df.shape
# Out:
# (18969, 49)

# %%
corr = df.drop(columns = ['user','churn']).corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f,ax=plt.subplots(figsize=(18,25))

cmap=sns.diverging_palette(250,10,as_cmap=True)
sns.heatmap(corr,mask=mask,cmap=cmap,robust=True,center=0,square=True, linewidths=.5,cbar_kws={"shrink":.5})

# %% [markdown]
# ## Function for removing the correlated columns
# Will remove the correlated columns above threshold value

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %% [markdown]
# ## Selecting best features

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns=['churn','user'])
y=df['churn']
# generate the datasets for training. Test 20%
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                   test_size = 0.2,
                                                   random_state = 0)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
bestfeatures = SelectKBest(score_func=chi2, k=20)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(20,'Score'))
# Out:
#                    Specs         Score
# 4     purchases_partners  95512.684676
# 7         cc_recommended  72126.302861
# 23        rewards_earned  14209.156360
# 2               deposits  10625.853182
# 5              purchases  10516.688826
# 10  cc_application_begin   5556.259558
# 1           credit_score   1806.845616
# 3             withdrawal    373.427947
# 24           reward_rate    365.799186
# 0                    age    224.189965
# 6               cc_taken    194.429945
# 8            cc_disliked     77.736809
# 25           is_referred     70.138056
# 28            housing_na     60.216112
# 19         received_loan     51.888476
# 20         rejected_loan     47.945564
# 26             housing_O     47.153286
# 32   payment_type_Weekly     46.265546
# 16     registered_phones     30.407214
# 22    left_for_one_month     22.442479

# %%
featureScores.head()
# Out:
#                 Specs         Score
# 0                 age    224.189965
# 1        credit_score   1806.845616
# 2            deposits  10625.853182
# 3          withdrawal    373.427947
# 4  purchases_partners  95512.684676

# %%
X.columns
# Out:
# Index(['age', 'credit_score', 'deposits', 'withdrawal', 'purchases_partners',
#        'purchases', 'cc_taken', 'cc_recommended', 'cc_disliked', 'cc_liked',
#        'cc_application_begin', 'app_downloaded', 'web_user', 'app_web_user',
#        'ios_user', 'android_user', 'registered_phones', 'waiting_4_loan',
#        'cancelled_loan', 'received_loan', 'rejected_loan',
#        'left_for_two_month_plus', 'left_for_one_month', 'rewards_earned',
#        'reward_rate', 'is_referred', 'housing_O', 'housing_R', 'housing_na',
#        'payment_type_Bi-Weekly', 'payment_type_Monthly',
#        'payment_type_Semi-Monthly', 'payment_type_Weekly', 'payment_type_na',
#        'zodiac_sign_Aquarius', 'zodiac_sign_Aries', 'zodiac_sign_Cancer',
#        'zodiac_sign_Capricorn', 'zodiac_sign_Gemini', 'zodiac_sign_Leo',
#        'zodiac_sign_Libra', 'zodiac_sign_Pisces', 'zodiac_sign_Sagittarius',
#        'zodiac_sign_Scorpio', 'zodiac_sign_Taurus', 'zodiac_sign_Virgo',
# ...

# %%
X=X.drop(columns=[])

# %%
X_train.shape
# Out:
# (15175, 47)

# %%
corr_features=correlation(X_train,0.85)
len(set(corr_features))
# Out:
# 5

# %%
corr_features
# Out:
# {'android_user', 'app_web_user', 'purchases', 'reward_rate', 'rewards_earned'}

# %%
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)

# %%
X_train.shape
# Out:
# (15175, 42)

# %%
X_train.columns
# Out:
# Index(['age', 'credit_score', 'deposits', 'withdrawal', 'purchases_partners',
#        'cc_taken', 'cc_recommended', 'cc_disliked', 'cc_liked',
#        'cc_application_begin', 'app_downloaded', 'web_user', 'ios_user',
#        'registered_phones', 'waiting_4_loan', 'cancelled_loan',
#        'received_loan', 'rejected_loan', 'left_for_two_month_plus',
#        'left_for_one_month', 'is_referred', 'housing_O', 'housing_R',
#        'housing_na', 'payment_type_Bi-Weekly', 'payment_type_Monthly',
#        'payment_type_Semi-Monthly', 'payment_type_Weekly', 'payment_type_na',
#        'zodiac_sign_Aquarius', 'zodiac_sign_Aries', 'zodiac_sign_Cancer',
#        'zodiac_sign_Capricorn', 'zodiac_sign_Gemini', 'zodiac_sign_Leo',
#        'zodiac_sign_Libra', 'zodiac_sign_Pisces', 'zodiac_sign_Sagittarius',
#        'zodiac_sign_Scorpio', 'zodiac_sign_Taurus', 'zodiac_sign_Virgo',
#        'zodiac_sign_na'],
#       dtype='object')

# %%
X_train.drop(columns='user',inplace=True)
X_test.drop(columns='user',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-ba4dc379a67b> in <module>
# ----> 1 X_train.drop(columns='user',inplace=True)
#       2 X_test.drop(columns='user',inplace=True)
#
# D:\installations\anaconda\envs\tensorflows\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# D:\installations\anaconda\envs\tensorflows\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
y_train.value_counts()
# Out:
# 0    8962
# 1    6213
# Name: churn, dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import LogisticRegression
from imblearn.ensemble import BalancedBaggingClassifier
lr=LogisticRegression(random_state=0, solver='lbfgs')
bbc = BalancedBaggingClassifier(base_estimator=lr,
                                sampling_strategy='auto',
                                replacement=False,
                                random_state=0)
bbc.fit(X_train,y_train)
# Out:
# BalancedBaggingClassifier(base_estimator=LogisticRegression(random_state=0),
#                           random_state=0)

# %%
y_predict=bbc.predict(X_test)

# %%
#print(lr.feature_importances_)

# %%
# Evaluating Result
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
cnf_matrix = confusion_matrix(y_test, y_predict)

# %%
# Accuracy score
accuracy_score(y_test, y_predict)
# Out:
# 0.6415392725355825

# %%
precision_score(y_test, y_predict)
# Out:
# 0.5529304861426624

# %%
recall_score(y_test, y_predict)
# Out:
# 0.7639673571876961

# %%
f1_score(y_test, y_predict)
# Out:
# 0.6415392725355825

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict,target_names=['class 0','class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.76      0.55      0.64      2201
#      class 1       0.55      0.76      0.64      1593
#
#     accuracy                           0.64      3794
#    macro avg       0.66      0.66      0.64      3794
# weighted avg       0.68      0.64      0.64      3794

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
print("Accuracy %0.4f" % accuracy_score(y_test, y_predict))
# Out:
# Accuracy 0.6415

# %% [markdown]
# ## Let's Try it by removing Outliers and by selecting 20 best features

# %%
selected_features=['purchases_partners','cc_recommended','rewards_earned','deposits','purchases','cc_application_begin',
                   'credit_score','withdrawal','reward_rate','age','cc_taken','cc_disliked','is_referred','housing_na',
                   'received_loan','rejected_loan','housing_O','payment_type_Weekly','registered_phones','left_for_one_month',
                  'churn']

# %%
df2=df[selected_features]

# %%
df2.head()
# Out:
#    purchases_partners  cc_recommended  rewards_earned  deposits  purchases  \
# 1                   1              96            44.0         0          0
# 2                  86             285            65.0        47         47
# 3                  38              74            33.0        26         25
# 5                 111             227            55.0         5          5
# 6                   4               0             2.0         0          0
#
#    cc_application_begin  credit_score  withdrawal  reward_rate   age  ...  \
# 1                     5         486.0           0         1.47  28.0  ...
# 2                     9         561.0           2         2.17  35.0  ...
# 3                    26         567.0           3         1.10  26.0  ...
# 5                    17         567.0           3         1.83  32.0  ...
# 6                     0         475.0           0         0.07  21.0  ...
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18969 entries, 1 to 26999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   purchases_partners    18969 non-null  int64
#  1   cc_recommended        18969 non-null  int64
#  2   rewards_earned        18969 non-null  float64
#  3   deposits              18969 non-null  int64
#  4   purchases             18969 non-null  int64
#  5   cc_application_begin  18969 non-null  int64
#  6   credit_score          18969 non-null  float64
#  7   withdrawal            18969 non-null  int64
#  8   reward_rate           18969 non-null  float64
#  9   age                   18969 non-null  float64
#  10  cc_taken              18969 non-null  int64
#  11  cc_disliked           18969 non-null  int64
#  12  is_referred           18969 non-null  int64
#  13  housing_na            18969 non-null  uint8
#  14  received_loan         18969 non-null  int64
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df2.corr(),annot=True)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
df2.shape
# Out:
# (18969, 21)

# %%
correlation(df2,0.85)
# Out:
# {'purchases', 'reward_rate', 'rewards_earned'}

# %%
df2=df2.drop(columns=['purchases', 'reward_rate', 'rewards_earned'])

# %%
df2.shape
# Out:
# (18969, 18)

# %%
df2.columns
# Out:
# Index(['purchases_partners', 'cc_recommended', 'deposits',
#        'cc_application_begin', 'credit_score', 'withdrawal', 'age', 'cc_taken',
#        'cc_disliked', 'is_referred', 'housing_na', 'received_loan',
#        'rejected_loan', 'housing_O', 'payment_type_Weekly',
#        'registered_phones', 'left_for_one_month', 'churn'],
#       dtype='object')

# %%
df2[['purchases_partners','cc_recommended','deposits']].boxplot()

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
df2=remove_outlier(df2,'purchases_partners')

# %%
df2=remove_outlier(df2,'deposits')

# %%
df2[['purchases_partners','cc_recommended','deposits']].boxplot()

# %%
df2.describe().T
# Out:
#                         count        mean        std   min    25%    50%  \
# purchases_partners    14897.0   22.109485  30.424790   0.0    0.0    6.0
# cc_recommended        14897.0   95.214943  83.183917   0.0   18.0   74.0
# deposits              14897.0    0.434718   0.927876   0.0    0.0    0.0
# cc_application_begin  14897.0    7.548835  10.132503   0.0    1.0    4.0
# credit_score          14897.0  541.904880  59.916530   2.0  507.0  541.0
# withdrawal            14897.0    0.102370   0.402804   0.0    0.0    0.0
# age                   14897.0   31.954085   9.617150  17.0   25.0   30.0
# cc_taken              14897.0    0.108075   0.538277   0.0    0.0    0.0
# cc_disliked           14897.0    0.069611   0.762596   0.0    0.0    0.0
# is_referred           14897.0    0.308451   0.461870   0.0    0.0    0.0
# housing_na            14897.0    0.472780   0.499275   0.0    0.0    0.0
# received_loan         14897.0    0.022353   0.147835   0.0    0.0    0.0
# ...

# %%
q1=df2['credit_score'].quantile(0.25)
q3=df2['credit_score'].quantile(0.75)
iqr=q3-q1
fence_low  = q1-1.5*iqr
fence_high = q3+1.5*iqr

# %%
print(fence_low)
# Out:
# 402.0

# %%
print(fence_high)
# Out:
# 682.0

# %%
X1=df2.drop(columns='churn')
y1=df2['churn']

# %%
y1.value_counts()
# Out:
# 0    8139
# 1    6758
# Name: churn, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X1,y1,
                                                   test_size = 0.2,
                                                   random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
from imblearn.ensemble import BalancedBaggingClassifier
lr=LogisticRegression(random_state=0, solver='lbfgs')
bbc = BalancedBaggingClassifier(base_estimator=lr,
                                sampling_strategy='auto',
                                replacement=False,
                                random_state=0)
bbc.fit(X_train,y_train)
# Out:
# BalancedBaggingClassifier(base_estimator=LogisticRegression(random_state=0),
#                           random_state=0)

# %%
y_pred=bbc.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6382550335570469

# %%
cnf_matrix = confusion_matrix(y_test, y_pred)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
print("Accuracy %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Accuracy 0.6383

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.52      0.61      1614
#            1       0.58      0.78      0.66      1366
#
#     accuracy                           0.64      2980
#    macro avg       0.66      0.65      0.64      2980
# weighted avg       0.66      0.64      0.63      2980
